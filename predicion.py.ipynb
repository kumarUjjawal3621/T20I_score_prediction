# %%
import pickle
import pandas as pd
dataset=pd.read_pickle('data_2.pkl')

# %%
len(dataset)
# Out:
# 795

# %%
dataset[0][0]
# Out:
#           dates outcome.winner  player_of_match                   teams  \
# 0  [2017-02-17]      Sri Lanka  [DAS Gunaratne]  [Australia, Sri Lanka]
#
#   toss.decision toss.winner                 umpires                     venue
# 0         field   Sri Lanka  [MD Martell, P Wilson]  Melbourne Cricket Ground

# %%
dataset[0][1]
# Out:
#      over      batsman non_striker           bowler  batsman_runs  extra_runs  \
# 0     0.1     AJ Finch   M Klinger       SL Malinga             0           0
# 1     0.2     AJ Finch   M Klinger       SL Malinga             0           0
# 2     0.3     AJ Finch   M Klinger       SL Malinga             1           0
# 3     0.4    M Klinger    AJ Finch       SL Malinga             2           0
# 4     0.5    M Klinger    AJ Finch       SL Malinga             0           0
# ..    ...          ...         ...              ...           ...         ...
# 120  19.3  JP Faulkner    TD Paine  KMDN Kulasekara             2           0
# 121  19.4  JP Faulkner    TD Paine  KMDN Kulasekara             0           1
# 122  19.5  JP Faulkner    TD Paine  KMDN Kulasekara             1           0
# 123  19.6  JP Faulkner  PJ Cummins  KMDN Kulasekara             2           0
# 124  19.7  JP Faulkner  PJ Cummins  KMDN Kulasekara             4           0
#
#      total_runs        extras  \
# ...

# %%
df=pd.dataframe()
for i in range(len(dataset)):
    
    new_row={ 'Batting_team':[dataset[i][0]], 'Fielding_team':[],
        
    }
